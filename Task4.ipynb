# %% [markdown]
# ### Import Moudle we need

# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ### Import data

# %%
# read Input/Task4/pepperImage.png with numpy
pepperRGB = np.load('Input/Task4/pepperImage.png')
pepperRGB = pepperRGB.astype(np.uint8)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[6], line 2
#       1 # read Input/Task4/pepperImage.png with numpy
# ----> 2 pepperRGB = np.load('Input/Task4/pepperImage.png')
#       3 pepperRGB = pepperRGB.astype(np.uint8)
#
# File ~/anaconda3/envs/medimg/lib/python3.12/site-packages/numpy/lib/npyio.py:462, in load(file, mmap_mode, allow_pickle, fix_imports, encoding, max_header_size)
#     459 else:
#     460     # Try a pickle
#     461     if not allow_pickle:
# --> 462         raise ValueError("Cannot load file containing pickled data "
#     463                          "when allow_pickle=False")
#     464     try:
#     465         return pickle.load(fid, **pickle_kwargs)
#
# ValueError: Cannot load file containing pickled data when allow_pickle=False

# %%
# read Input/Task4/pepperImage.png with plt
pepperRGB = plt.imread('Input/Task4/pepperImage.png')

# %% [markdown]
# ### Task 4.1
# - The file has a color image. Plot the image. Load the image using a RGB system. Then, the color image  can be described as  where R, G and B indicate the red, green and blue components, respectively in the RGB system. Plot and  using a gray-scale map.

# %% [markdown]
# - The file has a color image. Plot the image. Load the image using a RGB system.

# %%
plt.imshow(pepperRGB)

# %% [markdown]
# - Plot and  using a gray-scale map.

# %%
# read pepperImg as numpy array
pepperRGB = plt.imread('Input/Task4/pepperImage.png')
np.shape(pepperRGB)
# Out:
# (384, 512, 3)
